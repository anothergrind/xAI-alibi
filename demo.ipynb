# %%
# %pip install -q alibi
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\Kamsi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from alibi.datasets import fetch_adult

# %%
adult = fetch_adult()
data = adult.data
target = adult.target

# %%
print("Data:")
print(data)
# Out:
# Data:
# [[39  7  1 ...  0 40  9]
#  [50  6  1 ...  0 13  9]
#  [38  4  4 ...  0 40  9]
#  ...
#  [58  4  4 ...  0 40  9]
#  [22  4  4 ...  0 20  9]
#  [52  5  4 ...  0 40  9]]

# %%
print("Target: ")
print(target)
# Out:
# Target:
# [0 0 0 ... 0 0 1]

# %%
print(adult.data.shape, adult.target.shape)
# Out:
# (32561, 12) (32561,)
